# %%
import pandas as pd

# %%
fornecedores = pd.read_csv('dados/fornecedores.csv', sep = ';')

# %%
fornecedores.head(30)
# Out:
#     FornecedorID     FornecedorNome
# 0              1          USA Jeans
# 1              2      Global Outlet
# 2              3           Netshoes
# 3              4         All Sports
# 4              5   Tuxedo Beachwear
# 5              6          Surf Trip
# 6              7       Tennis Place
# 7              8         Sports Now
# 8              9        DSW Imports
# 9             10    Brazilian Style
# 10            11       Tinas Sports
# 11            12        Luis Vilton
# 12            13         Baby Place
# 13            14      Rossi Clothes
# 14            15           Fast Way
# 15            16        L.A. Sports
# 16            17      Roland Sports
# 17            18         Baby Dress
# 18            19     Donald Clothes
# 19            20     Wills Surfwear
# 20            21     Danske Treshoe
# 21            22  Lundenhagen Boots
# 22            23      Pälsii Sports
# 23            24     Great Outdoors
# 24            25      Patamonia Inc
# ...

# %%
transportadoras = pd.read_csv('dados/transportadoras.csv', sep = ';')

# %%
transportadoras.head(3)
# Out:
#    TransportadoraID TransportadoraNome
# 0                 1   General Shipping
# 1                 2     Global Express
# 2                 3    Great Logistics

# %%
vendasglobais = pd.read_csv('dados/VendasGlobais.csv', sep = ',')

# %%
vendasglobais.head(3000)
# Out:
#       PedidoID  CategoriaID  CategoriaNome CategoriaDescricao  ClienteID  \
# 0        10413            1  Men´s Clothes    Fashion for Men         41
# 1        10500            2    Womens wear  Fashion for Women         41
# 2        10832            2    Womens wear  Fashion for Women         41
# 3        10923            2    Womens wear  Fashion for Women         41
# 4        10413            2    Womens wear  Fashion for Women         41
# ...        ...          ...            ...                ...        ...
# 2167     11036            8       Babywear          0-3 Years         17
# 2168     10264            8       Babywear          0-3 Years         17
# 2169     10391            8       Babywear          0-3 Years         17
# 2170     10547            8       Babywear          0-3 Years         17
# 2171     10894            8       Babywear          0-3 Years         17
#
#                 ClienteNome     ClienteContato ClienteCidade ClientePaisID  \
# ...

# %%
vendasglobais = vendasglobais.dropna(axis=0, how='all')

# %%
len(vendasglobais.axes[0])
# Out:
# 2172

# %%
vendasglobais.head(3000)
# Out:
#       PedidoID  CategoriaID  CategoriaNome CategoriaDescricao  ClienteID  \
# 0        10413            1  Men´s Clothes    Fashion for Men         41
# 1        10500            2    Womens wear  Fashion for Women         41
# 2        10832            2    Womens wear  Fashion for Women         41
# 3        10923            2    Womens wear  Fashion for Women         41
# 4        10413            2    Womens wear  Fashion for Women         41
# ...        ...          ...            ...                ...        ...
# 2167     11036            8       Babywear          0-3 Years         17
# 2168     10264            8       Babywear          0-3 Years         17
# 2169     10391            8       Babywear          0-3 Years         17
# 2170     10547            8       Babywear          0-3 Years         17
# 2171     10894            8       Babywear          0-3 Years         17
#
#                 ClienteNome     ClienteContato ClienteCidade ClientePaisID  \
# ...

# %%
pd.DataFrame(vendasglobais.dtypes)
# Out:
#                          0
# PedidoID             int64
# CategoriaID          int64
# CategoriaNome       object
# CategoriaDescricao  object
# ClienteID            int64
# ClienteNome         object
# ClienteContato      object
# ClienteCidade       object
# ClientePaisID       object
# ClientePais         object
# Vendas Custo        object
# Margem Bruta        object
# Vendas              object
# Desconto            object
# Frete               object
# Qtde                 int64
# Data                object
# VendedorID           int64
# ProdutoID            int64
# ProdutoNome         object
# TransportadoraID     int64
# FornecedorID         int64

# %%
vendasglobais['Vendas Custo'] = vendasglobais['Vendas Custo'].str.replace(',', '.').astype(float)

# %%
vendasglobais['Vendas Custo'].head(10)
# Out:
# 0     417.5107
# 1      63.8885
# 2     961.5917
# 3    1354.1170
# 4    4810.2163
# 5    5985.2808
# 6     121.7160
# 7     298.4112
# 8    1005.8544
# 9     113.2488
# Name: Vendas Custo, dtype: float64

# %%
vendasglobais['Margem Bruta'] = vendasglobais['Margem Bruta'].str.replace(',', '.').astype(float)

# %%
vendasglobais['Vendas'] = vendasglobais['Vendas'].str.replace(',', '.').astype(float)

# %%
vendasglobais['Desconto'] = vendasglobais['Desconto'].str.replace(',', '.').astype(float)

# %%
vendasglobais['Frete'] = vendasglobais['Frete'].str.replace(',', '.').astype(float)

# %%
vendasglobais.head(10)
# Out:
#    PedidoID  CategoriaID  CategoriaNome CategoriaDescricao  ClienteID  \
# 0     10413            1  Men´s Clothes    Fashion for Men         41
# 1     10500            2    Womens wear  Fashion for Women         41
# 2     10832            2    Womens wear  Fashion for Women         41
# 3     10923            2    Womens wear  Fashion for Women         41
# 4     10413            2    Womens wear  Fashion for Women         41
# 5     10425            2    Womens wear  Fashion for Women         41
# 6     10832            3      Sportwear            Sports…         41
# 7     10425            3      Sportwear            Sports…         41
# 8     10413            3      Sportwear            Sports…         41
# 9     10923            4   Bath Clothes          Beachwear         41
#
#              ClienteNome ClienteContato ClienteCidade ClientePaisID  \
# 0  Elle Fashion & Design    Louise Davu      Toulouse           FRA
# ...

# %%
vendedores = pd.read_csv('dados/Vendedores.csv', sep = ';')

# %%
vendedores.head(10)
# Out:
#    VendedorID        VendedorNome
# 0           1        Gael Monfils
# 1           2      Martina Hingis
# 2           3      Yannick Sinner
# 3           4     Patrick Mcenroe
# 4           5  Stefanos Tsitsipas
# 5           6    Alexander Zverev
# 6           7    Helena Demetieva
# 7           8        Simona Halep
# 8           9          Cori Gauff

# %% [markdown]
# # 1. Quem são os meus 10 maiores clientes, em termos de vendas?

# %% [markdown]
# #### Filtrando pelas vendas

# %%
vendasglobais.groupby('ClienteID').sum()
# Out:
#            PedidoID  CategoriaID  Vendas Custo  Margem Bruta    Vendas  \
# ClienteID
# 1            877781          327    60280.4574      14873.12  75153.55
# 2            106954           39      864.9010        150.98   1015.88
# 3            180350           58     7018.5259       1966.42   8984.93
# 4             85119           24     5599.9757       1088.36   6688.34
# 5            552534          208    30675.6572       9163.25  39838.92
# ...             ...          ...           ...           ...       ...
# 88            10874            8       58.2120          7.79     66.00
# 89           427657          156    18183.2781       4538.31  22721.62
# 90            32730            9      394.0555         48.72    442.77
# 91           172639           52     3424.3374        552.84   3977.18
# 127           85679           37     5132.6748       1395.47   6528.14
#
#            Desconto    Frete  Qtde  VendedorID  ProdutoID  TransportadoraID  \
# ClienteID
# ...

# %%
selecao_pelas_vendas = vendasglobais.groupby(['ClienteID'], sort=True).sum().reset_index()
selecao_pelas_vendas = selecao_pelas_vendas.sort_values(by = ['Vendas'], ascending=False)
selecao_pelas_vendas
# Out:
#     ClienteID  PedidoID  CategoriaID  Vendas Custo  Margem Bruta     Vendas  \
# 61         63   1127434          405   160110.2102      41210.24  201320.49
# 18         19   1330274          512   119357.5503      32757.22  152114.80
# 36         37   1484404          556   101336.4468      29796.74  131133.21
# 22         23    768696          305    69937.4442      21424.73   91362.15
# 31         32   1304224          503    65859.2232      16660.62   82519.86
# ..        ...       ...          ...           ...           ...        ...
# 42         43     10545            1      219.9619         43.74     263.70
# 52         53     32561            5      198.0315         38.80     236.83
# 68         70     10639            8      156.6216         36.74     193.36
# 12         13     20518           11       91.3853         14.38     105.77
# 85         88     10874            8       58.2120          7.79      66.00
#
# ...

# %%
vendasglobais.groupby('ClienteID').agg(somatorio_vendas=('Vendas', 'sum'))
# Out:
#            somatorio_vendas
# ClienteID
# 1                  75153.55
# 2                   1015.88
# 3                   8984.93
# 4                   6688.34
# 5                  39838.92
# ...                     ...
# 88                    66.00
# 89                 22721.62
# 90                   442.77
# 91                  3977.18
# 127                 6528.14
#
# [90 rows x 1 columns]

# %%
vendasglobais.groupby(['ClienteID'])['Vendas'].sum().nlargest(10)
# Out:
# ClienteID
# 63    201320.49
# 19    152114.80
# 37    131133.21
# 23     91362.15
# 32     82519.86
# 1      75153.55
# 80     68265.67
# 44     65815.99
# 73     59976.96
# 79     50922.49
# Name: Vendas, dtype: float64

# %%
vendasglobais.loc[vendasglobais['ClienteID'].isin([63,19,37,23,32,1,80,44,73,79])].drop_duplicates(subset='ClienteID')
# Out:
#       PedidoID  CategoriaID  CategoriaNome CategoriaDescricao  ClienteID  \
# 45       10520            1  Men´s Clothes    Fashion for Men         37
# 239      10460            1  Men´s Clothes    Fashion for Men         19
# 455      10634            1  Men´s Clothes    Fashion for Men         23
# 669      10447            1  Men´s Clothes    Fashion for Men         32
# 920      10518            1  Men´s Clothes    Fashion for Men         80
# 1479     10708            1  Men´s Clothes    Fashion for Men         79
# 1527     10631            1  Men´s Clothes    Fashion for Men         44
# 1667     11005            1  Men´s Clothes    Fashion for Men          1
# 1871     10883            1  Men´s Clothes    Fashion for Men         63
# 2035     10275            1  Men´s Clothes    Fashion for Men         73
#
#            ClienteNome       ClienteContato   ClienteCidade ClientePaisID  \
# 45             Boleros        Robert Bolero            Cork           IRL
# ...

# %% [markdown]
# #### Filtrando pelo lucro obtido (margem bruta)

# %%
vendasglobais.groupby(['ClienteID'])['Margem Bruta'].sum().nlargest(10)
# Out:
# ClienteID
# 63    41210.24
# 19    32757.22
# 37    29796.74
# 23    21424.73
# 32    16660.62
# 1     14873.12
# 80    13126.81
# 44    12991.10
# 73    12381.94
# 59     9764.84
# Name: Margem Bruta, dtype: float64

# %%
vendasglobais.loc[vendasglobais['ClienteID'].isin([63,19,37,23,32,1,80,44,73,59])].drop_duplicates(subset='ClienteID')
# Out:
#       PedidoID  CategoriaID  CategoriaNome CategoriaDescricao  ClienteID  \
# 45       10520            1  Men´s Clothes    Fashion for Men         37
# 239      10460            1  Men´s Clothes    Fashion for Men         19
# 455      10634            1  Men´s Clothes    Fashion for Men         23
# 669      10447            1  Men´s Clothes    Fashion for Men         32
# 920      10518            1  Men´s Clothes    Fashion for Men         80
# 1350     10773            1  Men´s Clothes    Fashion for Men         59
# 1527     10631            1  Men´s Clothes    Fashion for Men         44
# 1667     11005            1  Men´s Clothes    Fashion for Men          1
# 1871     10883            1  Men´s Clothes    Fashion for Men         63
# 2035     10275            1  Men´s Clothes    Fashion for Men         73
#
#            ClienteNome       ClienteContato   ClienteCidade ClientePaisID  \
# 45             Boleros        Robert Bolero            Cork           IRL
# ...

# %% [markdown]
# #### Filtrando pela quantidade

# %%
vendasglobais.groupby(['ClienteID'])['Qtde'].sum().nlargest(10)
# Out:
# ClienteID
# 63    4552
# 37    3871
# 19    3467
# 32    3211
# 1     2071
# 23    1875
# 44    1772
# 73    1757
# 80    1542
# 25    1525
# Name: Qtde, dtype: int64

# %%
vendasglobais.loc[vendasglobais['ClienteID'].isin([63,37,19,32,1,23,44,73,80,25])].drop_duplicates(subset='ClienteID')
# Out:
#       PedidoID  CategoriaID  CategoriaNome CategoriaDescricao  ClienteID  \
# 45       10520            1  Men´s Clothes    Fashion for Men         37
# 239      10460            1  Men´s Clothes    Fashion for Men         19
# 455      10634            1  Men´s Clothes    Fashion for Men         23
# 669      10447            1  Men´s Clothes    Fashion for Men         32
# 920      10518            1  Men´s Clothes    Fashion for Men         80
# 1094     10623            1  Men´s Clothes    Fashion for Men         25
# 1527     10631            1  Men´s Clothes    Fashion for Men         44
# 1667     11005            1  Men´s Clothes    Fashion for Men          1
# 1871     10883            1  Men´s Clothes    Fashion for Men         63
# 2035     10275            1  Men´s Clothes    Fashion for Men         73
#
#            ClienteNome       ClienteContato   ClienteCidade ClientePaisID  \
# 45             Boleros        Robert Bolero            Cork           IRL
# ...

# %% [markdown]
# ##### Clientes que mais aparecem em termos de frequencia na tabela

# %%
#O valor mais frequente:
vendasglobais['ClienteID'].mode()
# Out:
# 0    37
# dtype: int64

# %%
selecao1 = vendasglobais['ClienteID'] == 37
n1 = vendasglobais[selecao1].shape[0]
n1
# Out:
# 140

# %%
vendasglobais.loc[vendasglobais['ClienteID'] == 37]
# Out:
#      PedidoID  CategoriaID  CategoriaNome CategoriaDescricao  ClienteID  \
# 45      10520            1  Men´s Clothes    Fashion for Men         37
# 46      10722            1  Men´s Clothes    Fashion for Men         37
# 47      10312            1  Men´s Clothes    Fashion for Men         37
# 48      11003            1  Men´s Clothes    Fashion for Men         37
# 49      10309            1  Men´s Clothes    Fashion for Men         37
# ..        ...          ...            ...                ...        ...
# 180     10897            8       Babywear          0-3 Years         37
# 181     10678            8       Babywear          0-3 Years         37
# 182     11002            8       Babywear          0-3 Years         37
# 183     10661            8       Babywear          0-3 Years         37
# 184     10373            8       Babywear          0-3 Years         37
#
#     ClienteNome ClienteContato ClienteCidade ClientePaisID ClientePais  ...  \
# ...

# %%
# Os 10 clientes mais frequentes da tabela vendas globais com a quantidade de vezes que aparecem
vendasglobais['ClienteID'].value_counts()[:5].sort_values(ascending=False)
# Out:
# 37    140
# 19    125
# 32    122
# 63    106
# 73     92
# Name: ClienteID, dtype: int64

# %%
vendasglobais['ClienteID'].value_counts()[:10].index.tolist()
# Out:
# [37, 19, 32, 63, 73, 1, 23, 44, 80, 82]

# %%
vendasglobais.loc[vendasglobais['ClienteID'].isin([37, 19, 32, 63, 73, 1, 23, 44, 80, 82])].drop_duplicates(subset='ClienteID')
# Out:
#       PedidoID  CategoriaID  CategoriaNome CategoriaDescricao  ClienteID  \
# 45       10520            1  Men´s Clothes    Fashion for Men         37
# 239      10460            1  Men´s Clothes    Fashion for Men         19
# 455      10634            1  Men´s Clothes    Fashion for Men         23
# 571      10358            1  Men´s Clothes    Fashion for Men         82
# 669      10447            1  Men´s Clothes    Fashion for Men         32
# 920      10518            1  Men´s Clothes    Fashion for Men         80
# 1527     10631            1  Men´s Clothes    Fashion for Men         44
# 1667     11005            1  Men´s Clothes    Fashion for Men          1
# 1871     10883            1  Men´s Clothes    Fashion for Men         63
# 2035     10275            1  Men´s Clothes    Fashion for Men         73
#
#            ClienteNome       ClienteContato   ClienteCidade ClientePaisID  \
# 45             Boleros        Robert Bolero            Cork           IRL
# ...

# %% [markdown]
# # 2. Quais os três maiores países, em termos de vendas ()?

# %% [markdown]
# #### Filtrando pelas vendas

# %%
vendasglobais.groupby(['ClientePais'])['Vendas'].sum().nlargest(3)
# Out:
# ClientePais
# Germany    519553.87
# USA        186313.27
# France     175565.32
# Name: Vendas, dtype: float64

# %% [markdown]
# # 3. Quais as categorias de produtos que geram maior faturamento (vendas no Brasil?

# %% [markdown]
# #### Filtrando pelas vendas

# %%
vendasglobais.groupby(['CategoriaID'])['Vendas'].sum().nlargest(5)
# Out:
# CategoriaID
# 2    680927.62
# 3    292017.88
# 6    251159.12
# 5    147568.81
# 1    139150.20
# Name: Vendas, dtype: float64

# %%
vendasglobais.loc[vendasglobais['CategoriaID'].isin([2,3,6,5,1])].drop_duplicates(subset='CategoriaID')
# Out:
#     PedidoID  CategoriaID    CategoriaNome CategoriaDescricao  ClienteID  \
# 0      10413            1    Men´s Clothes    Fashion for Men         41
# 1      10500            2      Womens wear  Fashion for Women         41
# 6      10832            3        Sportwear            Sports…         41
# 10     10832            5  Ladies´Footwear       Ladies Shoes         41
# 29     10814            6   Men´s Footwear          Men Shoes         84
#
#               ClienteNome ClienteContato ClienteCidade ClientePaisID  \
# 0   Elle Fashion & Design    Louise Davu      Toulouse           FRA
# 1   Elle Fashion & Design    Louise Davu      Toulouse           FRA
# 6   Elle Fashion & Design    Louise Davu      Toulouse           FRA
# 10  Elle Fashion & Design    Louise Davu      Toulouse           FRA
# 29         Art et Fashion  Pierre Robert          Lyon           FRA
#
#    ClientePais  ...  Vendas  Desconto  Frete  Qtde        Data  VendedorID  \
# ...

# %% [markdown]
# # 4. Qual a despesa com frete envolvendo cada transportadora?

# %%
vendasglobais.groupby(['TransportadoraID'])['Frete'].sum()
# Out:
# TransportadoraID
# 1    19843.83
# 2    70897.82
# 3    18771.69
# Name: Frete, dtype: float64

# %% [markdown]
# # 5. Quais são os principais clientes (vendas) do segmento “Calçados Masculinos” (Men´s Footwear) na Alemanha?

# %% [markdown]
# #### Filtrando pelas vendas

# %%
selecao_calcados_masculinos = (vendasglobais['ClientePais'] == 'Germany') & (vendasglobais['CategoriaID'] == 6)
dados_selecao_calcados_masculinos = vendasglobais[selecao_calcados_masculinos]
agrupando_selecao_calcados_masculinos = dados_selecao_calcados_masculinos.groupby(['ClienteID'])['Vendas'].sum().nlargest(5)
agrupando_selecao_calcados_masculinos
# Out:
# ClienteID
# 63    20488.49
# 17    11923.35
# 79    11235.97
# 1     10377.83
# 44     9085.77
# Name: Vendas, dtype: float64

# %%
vendasglobais.loc[vendasglobais['ClienteID'].isin([63,17,79,1,44])].drop_duplicates(subset='ClienteID')
# Out:
#       PedidoID  CategoriaID  CategoriaNome CategoriaDescricao  ClienteID  \
# 1479     10708            1  Men´s Clothes    Fashion for Men         79
# 1527     10631            1  Men´s Clothes    Fashion for Men         44
# 1667     11005            1  Men´s Clothes    Fashion for Men          1
# 1871     10883            1  Men´s Clothes    Fashion for Men         63
# 2127     10363            1  Men´s Clothes    Fashion for Men         17
#
#       ClienteNome       ClienteContato   ClienteCidade ClientePaisID  \
# 1479   Boombastic          Heinz Disco         Münster           DEU
# 1527      Warp AG           Klaus Deum  Frankfurt a.M.           DEU
# 1667  Eintrach GS  Albert von Einstein          Berlin           DEU
# 1871    Grunewald         George Essen       Cunewalde           DEU
# 2127  Gluderstedt    Lars von Holstein          Aachen           DEU
#
#      ClientePais  ...  Vendas  Desconto  Frete  Qtde        Data  VendedorID  \
# ...

# %% [markdown]
# # 6. Quais os vendedores que mais dão descontos nos Estados Unidos?

# %%
#a diferença entre o preco do produto e o desconto aplicado é grande?

# %%
#Somando todos os descontos dados pelo vendedor
selecao_vendedores_desconto_USA2 =  (vendasglobais['ClientePaisID'] == 'USA')
dados_selecao_vendedores_desconto_USA2 = vendasglobais[selecao_vendedores_desconto_USA2]
agrupando_selecao_vendedores_desconto_USA2 = dados_selecao_vendedores_desconto_USA2.groupby(['VendedorID'])['Desconto'].sum().nlargest(5)
agrupando_selecao_vendedores_desconto_USA2
# Out:
# VendedorID
# 1    7415.17
# 3    1160.05
# 2     733.79
# 9     404.55
# Name: Desconto, dtype: float64

# %% [markdown]
# # 7. Quais os fornecedores que dao a maior margem de lucro () no segmento de “Vestuário Feminino” (Womens wear)?

# %%
selecao_fornecedores_womens_wear =  (vendasglobais['CategoriaID'] == 2)
dados_selecao_fornecedores_womens_wear = vendasglobais[selecao_fornecedores_womens_wear]
agrupando_selecao_fornecedores_womens_wear = dados_selecao_fornecedores_womens_wear.groupby(['FornecedorID'])['Margem Bruta'].sum().nlargest(20)
agrupando_selecao_fornecedores_womens_wear
# Out:
# FornecedorID
# 23    81839.96
# 18    20675.19
# 20    10019.11
# 24     9165.03
# 2      4885.00
# 16     2304.59
# 12     2192.43
# 7      1845.28
# 3      1810.75
# 1      1273.99
# 6       147.61
# Name: Margem Bruta, dtype: float64

# %% [markdown]
# # 8. Quanto que foi vendido () no ano de 2009? Analisando as vendas anuais entre 2009 e 2012, podemos concluir que o faturamento vem crescendo, se mantendo estável ou decaindo?

# %%
vendasglobais['Data'] = pd.to_datetime(vendasglobais['Data'],format='%d/%m/%Y')

# %%
vendasglobais['Data']
# Out:
# 0      2010-10-20
# 1      2011-04-14
# 2      2011-11-19
# 3      2012-06-05
# 4      2010-10-20
#           ...
# 2167   2012-03-25
# 2168   2011-05-29
# 2169   2010-10-29
# 2170   2011-04-28
# 2171   2012-06-23
# Name: Data, Length: 2172, dtype: datetime64[ns]

# %%
selecao_vendido_2009 =  (vendasglobais['Data'].map(lambda dt: dt.strftime('%Y')) == '2009')
#>= pd.Timestamp(date(2009,1,1))) & (vendasglobais['Data'] <= pd.Timestamp(date(2009,12,31)))
dados_selecao_vendido_2009 = vendasglobais[selecao_vendido_2009]
agrupando_selecao_vendido_2009 = dados_selecao_vendido_2009['Vendas'].sum()
agrupando_selecao_vendido_2009
# Out:
# 87666.29000000001

# %%
#Analise de 2009 a 2012
#criando uma coluna com apenas o anopara facilitar
vendasglobais['apenasAno'] = vendasglobais['Data'].map(lambda dt: dt.strftime('%Y'))

# %%
#from datetime import date

# %%
# selecao_vendido_2009_a_2012 =  (vendasglobais['Data']>= pd.Timestamp(date(2009,1,1))) & (vendasglobais['Data'] <= pd.Timestamp(date(2012,12,31)))
# dados_selecao_vendido_2009_a_2012 = vendasglobais[selecao_vendido_2009_a_2012]
# agrupando_selecao_vendido_2009_a_2012 = vendasglobais.groupby(['apenasAno'])['Vendas'].sum()
# agrupando_selecao_vendido_2009_a_2012
# Out:
# apenasData
# 2009     87666.29
# 2010    370788.62
# 2011    641719.63
# 2012    682973.65
# Name: Vendas, dtype: float64

# %%
selecao_vendido_2009_a_2012_2 =  (vendasglobais['apenasData'].isin(['2009','2010','2011','2012']))
dados_selecao_vendido_2009_a_2012_2 = vendasglobais[selecao_vendido_2009_a_2012_2]
agrupando_selecao_vendido_2009_a_2012_2 = dados_selecao_vendido_2009_a_2012_2.groupby(['apenasData'])['Vendas'].sum()
agrupando_selecao_vendido_2009_a_2012_2
# Out:
# apenasData
# 2009     87666.29
# 2010    370788.62
# 2011    641719.63
# 2012    682973.65
# Name: Vendas, dtype: float64

# %% [markdown]
# # 9. Quais são os principais clientes (vendas) do segmento “Calçados Masculinos” (Men´s Footwear) na Alemanha?

# %%
selecao_calcados_masculinos2 = (vendasglobais['ClientePaisID'] == 'DEU') & (vendasglobais['CategoriaID'] == 6)
dados_selecao_calcados_masculinos2 = vendasglobais[selecao_calcados_masculinos]
agrupando_selecao_calcados_masculinos2 = dados_selecao_calcados_masculinos.groupby(['ClienteID'])['Vendas'].sum().nlargest(5)
agrupando_selecao_calcados_masculinos2
# Out:
# ClienteID
# 63    20488.49
# 17    11923.35
# 79    11235.97
# 1     10377.83
# 44     9085.77
# Name: Vendas, dtype: float64

# %%
vendasglobais.loc[vendasglobais['ClienteID'].isin([63,17,79,1,44])].drop_duplicates(subset='ClienteID')
# Out:
#       PedidoID  CategoriaID  CategoriaNome CategoriaDescricao  ClienteID  \
# 1479     10708            1  Men´s Clothes    Fashion for Men         79
# 1527     10631            1  Men´s Clothes    Fashion for Men         44
# 1667     11005            1  Men´s Clothes    Fashion for Men          1
# 1871     10883            1  Men´s Clothes    Fashion for Men         63
# 2127     10363            1  Men´s Clothes    Fashion for Men         17
#
#       ClienteNome       ClienteContato   ClienteCidade ClientePaisID  \
# 1479   Boombastic          Heinz Disco         Münster           DEU
# 1527      Warp AG           Klaus Deum  Frankfurt a.M.           DEU
# 1667  Eintrach GS  Albert von Einstein          Berlin           DEU
# 1871    Grunewald         George Essen       Cunewalde           DEU
# 2127  Gluderstedt    Lars von Holstein          Aachen           DEU
#
#      ClientePais  ...  Vendas  Desconto  Frete  Qtde        Data  VendedorID  \
# ...

# %% [markdown]
# # 10. Quais os países nos quais mais se tiram pedidos (qtde total de pedidos)?

# %%
vendasglobais.groupby(['ClientePais'])['Qtde'].sum().nlargest(10)
# Out:
# ClientePais
# Germany      14093
# USA           6689
# UK            4176
# Ireland       3871
# France        3619
# Brazil        3430
# Venezuela     3051
# Canada        2267
# Mexico        2183
# Denmark       1757
# Name: Qtde, dtype: int64
